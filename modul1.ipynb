# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv
import pandas as pd

# %%
img = cv.imread('aang.jpg')
imgGray = cv.cvtColor(img, cv.COLOR_RGB2GRAY)
cv.imwrite('grayaang.jpg', imgGray)
cv.imshow('coloraang', img)
cv.imshow('grayaang', imgGray)
cv.destroyAllWindows()

# %%
img = cv.imread('grayaang.jpg')
y = 444
h = 444
x = 444
w = 444

crop_img = img[y:y+h, x:x+w]

cv.imwrite('cropped_gray_aang.jpg', crop_img)
cv.imshow('cropped_gray_aang', crop_img)
cv.destroyAllWindows()

# %%
imgGray = cv2.imread('grayaang.jpg', cv2.IMREAD_COLOR)

imgGray = imgGray.astype('float32')

gambar_normalisasi = imgGray / 255.0

# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('grayaang.jpg',0)

hist = cv2.calcHist([img],[0],None,[256],[0,256])

plt.plot(hist)
plt.show()
